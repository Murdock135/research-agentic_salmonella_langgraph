# %%
from pathlib import Path
from dotenv import load_dotenv

def load_env_vars():
    # load ~/.secrets/.llm_apis
    load_dotenv(dotenv_path=Path.home() / ".secrets/.llm_apis")

    # load project .env
    load_dotenv()
    
load_env_vars()

def load_text(file_path):
    """Loads text from a file."""
    with open(file_path, 'r') as f:
        text = f.read()

    return text

def load_data_manifest(path_to_manifest_file) -> dict[str, dict[str, str]]:
    """
    Load a data manifest file and return its contents.
    """
    import json
    import os
    
    if not os.path.exists(path_to_manifest_file):
        raise FileNotFoundError(f"Manifest file not found: {path_to_manifest_file}")
    
    with open(path_to_manifest_file, 'r') as f:
        manifest: dict = json.load(f)
    
    return manifest

def get_data_repoIDs(path_to_manifest_file):
    """
    Get the repository IDs of datasets from the manifest file.
    """
    manifest = load_data_manifest(path_to_manifest_file)
    repo_ids = {dataset: info['repo_id'] for dataset, info in manifest.items() if 'repo_id' in info}
    
    return repo_ids

# %%
from langchain_core.tools import tool

@tool
def get_cached_dataset_path(repo_id: str):
    """ Get the path to a cached dataset from Hugging Face Hub.
    Args:
        repo_id (str): The repository ID of the dataset on Hugging Face Hub.
    Returns:
        Path: The path to the cached dataset.
    """
    from huggingface_hub import snapshot_download
    import os
    from pathlib import Path
    
    # Load HF Token
    HF_TOKEN = os.getenv("HF_TOKEN")
    if HF_TOKEN is None:
        raise ValueError("HF_TOKEN environment variable is not set. Please set it before running the script.")
    
    # get path to cached dataset
    path = snapshot_download(repo_id=repo_id, repo_type="dataset", token=HF_TOKEN)

    return Path(path)

@tool
def get_glob_files(repo_id):
    """
    Get list of files in a directory of all patterns"""

    path: Path = get_cached_dataset_path.invoke(repo_id)

    files = []
    for _ in path.rglob("*"):
        if not _.is_file():
            raise ValueError(f"Path {path} is not a file. Please provide a valid file path.")
        
        print(_)
        files.append(_)
        
    return files

@tool
def find_csv_excel_files(root_dir: Path) -> list[Path]:
    """
    Recursively find all CSV and Excel files in a directory.
    
    Args:
        root_dir (Path): Root directory to search.
    
    Returns:
        List[Path]: List of file paths with .csv, .xls, or .xlsx extensions.
    """
    if not root_dir.is_dir():
        raise NotADirectoryError(f"{root_dir} is not a valid directory")

    exts = {'.csv', '.xls', '.xlsx'}
    return [f for f in root_dir.rglob("*") if f.suffix.lower() in exts]

# %%
REPO_ID = "zayanhugsAI/pulsenet"

# %%
get_cached_dataset_path(REPO_ID)
# Out:
# Fetching 8 files: 100%|██████████| 8/8 [00:00<00:00, 50231.19it/s]
# PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107')

# %%
location = get_cached_dataset_path(REPO_ID)
get_glob_files(REPO_ID)
# Out:
# Fetching 8 files: 100%|██████████| 8/8 [00:00<00:00, 211034.16it/s]
# Fetching 8 files: 100%|██████████| 8/8 [00:00<00:00, 182361.04it/s]
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_2001-2005.xlsx
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_2020-2023.xlsx
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_2006-2010.xlsx
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_1996-2000.xlsx
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_2016-2019.xlsx
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/.gitattributes
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Data Dictionary.xlsx
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_2011-2015.xlsx
# [PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_2001-2005.xlsx'),
#  PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_2020-2023.xlsx'),
#  PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_2006-2010.xlsx'),
#  PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_1996-2000.xlsx'),
#  PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_2016-2019.xlsx'),
#  PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/.gitattributes'),
#  PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Data Dictionary.xlsx'),
#  PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107/Export_2011-2015.xlsx')]

# %%
print("="*50)
print("PulseNet")
print("="*50)

import pandas as pd

pulsenet_2016_to_2019 = location / "Export_2016-2019.xlsx"
sheet_names = pd.ExcelFile(pulsenet_2016_to_2019).sheet_names
print("Sheet names")
print("-"*50)
print(sheet_names)
print("-"*50)

df_2016_to_2019 = pd.read_excel(pulsenet_2016_to_2019, sheet_name=sheet_names[0])
print("Columns")
print("-"*50)
print(df_2016_to_2019.columns)
print("-"*50)

df_2016_to_2019.head()
# Out:
# ==================================================
# PulseNet
# ==================================================
# Sheet names
# --------------------------------------------------
# ['2016-2019']
# --------------------------------------------------
# Columns
# --------------------------------------------------
# Index(['Key', 'AntigenForm', 'AntigenForm_wgs', 'IsolatDate', 'LabID',
#        'Outbreak', 'PatientAgeDays', 'PatientAgeMonths', 'PatientAgeYears',
#        'PatientSex', 'PulseNet_UploadDate', 'Serotype', 'Serotype_wgs',
#        'SourceCity', 'SourceCountry', 'SourceCounty', 'SourceSite',
#        'SourceState', 'SourceType', 'TypeDetails', 'WGS_id'],
#       dtype='object')
# --------------------------------------------------
#                  Key AntigenForm AntigenForm_wgs           IsolatDate LabID  \
# 0     CA___M15X07392         NaN             NaN  2015-12-21 00:00:00    CA
# 1     CA___M15X07395         NaN             NaN  2015-12-22 00:00:00    CA
# 2    GA___16C0051284         NaN             NaN  2015-11-27 00:00:00    GA
# 3  TX___TXAML1505350         NaN             NaN  2015-12-20 00:00:00    TX
# 4  TX___TXAML1505348         NaN       I 7:r:1,5  2015-12-21 00:00:00    TX
#
#   Outbreak  PatientAgeDays  PatientAgeMonths PatientAgeYears PatientSex  ...  \
# 0      NaN             NaN               NaN              23     FEMALE  ...
# 1      NaN             NaN               NaN              80       MALE  ...
# 2      NaN             NaN               NaN              63     FEMALE  ...
# 3      NaN             NaN               NaN               6       MALE  ...
# 4      NaN             NaN               NaN              72       MALE  ...
#
#            Serotype Serotype_wgs SourceCity SourceCountry SourceCounty  \
# 0       Enteritidis          NaN    Oakland           USA      Alameda
# 1  Serotype pending          NaN   Berkeley           USA      Alameda
# 2           Javiana          NaN    Pearson           USA     Atkinson
# 3          Adelaide          NaN     Temple           USA         Bell
# 4          Infantis     Infantis     Temple           USA         Bell
#
#   SourceSite SourceState SourceType TypeDetails       WGS_id
# 0      Stool          CA      Human         NaN          NaN
# 1      Stool          CA      Human         NaN          NaN
# 2      Stool          GA      Human         NaN          NaN
# 3      Stool          TX      Human         NaN          NaN
# 4      Stool          TX      Human         NaN  2015AM-2845
#
# [5 rows x 21 columns]

# %%
REPO_ID = "zayanhugsAI/social_vulnerability_index"
get_cached_dataset_path(REPO_ID)
# Out:
# Fetching 3 files: 100%|██████████| 3/3 [00:00<00:00, 61082.10it/s]
# PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--social_vulnerability_index/snapshots/9bb6f44cb04883ba56fd228c4ca50b922d0a4e1f')

# %%
get_glob_files(REPO_ID)
# Out:
# Fetching 3 files: 100%|██████████| 3/3 [00:00<00:00, 77195.78it/s]
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--social_vulnerability_index/snapshots/9bb6f44cb04883ba56fd228c4ca50b922d0a4e1f/SVI_2020_US_county.csv
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--social_vulnerability_index/snapshots/9bb6f44cb04883ba56fd228c4ca50b922d0a4e1f/SVI_2022_US_county.csv
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--social_vulnerability_index/snapshots/9bb6f44cb04883ba56fd228c4ca50b922d0a4e1f/.gitattributes
# [PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--social_vulnerability_index/snapshots/9bb6f44cb04883ba56fd228c4ca50b922d0a4e1f/SVI_2020_US_county.csv'),
#  PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--social_vulnerability_index/snapshots/9bb6f44cb04883ba56fd228c4ca50b922d0a4e1f/SVI_2022_US_county.csv'),
#  PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--social_vulnerability_index/snapshots/9bb6f44cb04883ba56fd228c4ca50b922d0a4e1f/.gitattributes')]

# %%
import pandas as pd

REPO_ID = "zayanhugsAI/census_population"
location = get_cached_dataset_path(REPO_ID)
print(location)
data_files = find_csv_excel_files.invoke({'root_dir': location})
print(data_files)


data_file = data_files[0]

df = pd.read_excel(data_file)
df.head()
# Out:
# Fetching 3 files: 100%|██████████| 3/3 [00:00<00:00, 38362.54it/s]
# /Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--census_population/snapshots/5a1680c29c93aae1cce72c3443c1afed4ec631cb
# [PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--census_population/snapshots/5a1680c29c93aae1cce72c3443c1afed4ec631cb/2020-2023.xlsx'), PosixPath('/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--census_population/snapshots/5a1680c29c93aae1cce72c3443c1afed4ec631cb/states/mo_2020_to_2023.xlsx')]
#   table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 0  Annual Estimates of the Resident Population fo...
# 1                                    Geographic Area
# 2                                                NaN
# 3                                      United States
# 4                           .Autauga County, Alabama
#
#                      Unnamed: 1                          Unnamed: 2  \
# 0                           NaN                                 NaN
# 1  April 1, 2020 Estimates Base  Population Estimate (as of July 1)
# 2                           NaN                                2020
# 3                     331464948                           331526933
# 4                         58809                               58915
#
#     Unnamed: 3   Unnamed: 4   Unnamed: 5
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2       2021.0       2022.0       2023.0
# 3  332048977.0  333271411.0  334914895.0
# 4      59203.0      59726.0      60342.0

# %%
df
# Out:
#       ST    STATE ST_ABBR  STCNTY             COUNTY   FIPS  \
# 0      1  Alabama      AL    1001     Autauga County   1001
# 1      1  Alabama      AL    1003     Baldwin County   1003
# 2      1  Alabama      AL    1005     Barbour County   1005
# 3      1  Alabama      AL    1007        Bibb County   1007
# 4      1  Alabama      AL    1009      Blount County   1009
# ...   ..      ...     ...     ...                ...    ...
# 3139  56  Wyoming      WY   56037  Sweetwater County  56037
# 3140  56  Wyoming      WY   56039       Teton County  56039
# 3141  56  Wyoming      WY   56041       Uinta County  56041
# 3142  56  Wyoming      WY   56043    Washakie County  56043
# 3143  56  Wyoming      WY   56045      Weston County  56045
#
#                         LOCATION     AREA_SQMI  E_TOTPOP  M_TOTPOP  ...  \
# 0        Autauga County, Alabama    594.454786     58761         0  ...
# 1        Baldwin County, Alabama   1589.861817    233420         0  ...
# 2        Barbour County, Alabama    885.007619     24877         0  ...
# 3           Bibb County, Alabama    622.469286     22251         0  ...
# 4         Blount County, Alabama    644.890376     59077         0  ...
# ...                          ...           ...       ...       ...  ...
# 3139  Sweetwater County, Wyoming  10426.975770     42079         0  ...
# 3140       Teton County, Wyoming   3996.846933     23346         0  ...
# 3141       Uinta County, Wyoming   2081.719807     20546         0  ...
# 3142    Washakie County, Wyoming   2238.678265      7725         0  ...
# 3143      Weston County, Wyoming   2398.003893      6870         0  ...
#
#       EP_ASIAN  MP_ASIAN  EP_AIAN  MP_AIAN  EP_NHPI  MP_NHPI  EP_TWOMORE  \
# 0          1.1       0.4      0.1      0.1      0.0      0.1         3.3
# 1          0.9       0.1      0.2      0.1      0.0      0.1         3.1
# 2          0.5       0.1      0.3      0.1      0.0      0.1         1.8
# 3          0.3       0.4      0.1      0.1      0.0      0.2         1.7
# 4          0.2       0.2      0.1      0.1      0.2      0.2         2.8
# ...        ...       ...      ...      ...      ...      ...         ...
# 3139       0.7       0.3      0.9      0.3      0.1      0.1         2.2
# 3140       1.3       0.5      0.1      0.2      0.1      0.1         2.3
# 3141       0.2       0.2      0.1      0.1      0.0      0.2         2.9
# 3142       0.4       0.4      0.3      0.4      0.0      0.5         3.2
# 3143       0.2       0.4      1.5      1.2      0.7      1.2         8.3
#
#       MP_TWOMORE  EP_OTHERRACE  MP_OTHERRACE
# 0            1.0           0.2           0.3
# 1            0.4           0.4           0.3
# 2            0.7           1.2           0.8
# 3            1.0           0.1           0.1
# 4            0.7           0.1           0.1
# ...          ...           ...           ...
# 3139         0.8           0.9           0.7
# 3140         1.0           0.7           0.7
# 3141         0.4           0.0           0.2
# 3142         0.7           0.3           0.3
# 3143         3.5           0.1           0.2
#
# [3144 rows x 158 columns]

# %%
import os

manifest_path = "/Users/zayan/Documents/code/mine/research-agentic_salmonella_langgraph/data/data_manifest.json"
if not os.path.exists(manifest_path):
    raise FileNotFoundError(f"Manifest file does not exist at {manifest_path}. Please check the path.")

manifest = load_text(manifest_path)
manifest
# Out:
# '{\n    "census_population": {\n        "cache_location": "/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--census_population/snapshots/5a1680c29c93aae1cce72c3443c1afed4ec631cb",\n        "repo_id": "zayanhugsAI/census_population"\n    },\n    "naco": {\n        "cache_location": "/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--naco/snapshots/654328b4f5b5aa3150d26fb4e5e669b77b0419ef",\n        "repo_id": "zayanhugsAI/naco"\n    },\n    "nors": {\n        "cache_location": "/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--nors/snapshots/470514dec8d88f26a7186344f7f511fa372ddd8e",\n        "repo_id": "zayanhugsAI/nors"\n    },\n    "pulsenet": {\n        "cache_location": "/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--pulsenet/snapshots/93b6ba578b340211d67ea353e77ed917ad798107",\n        "repo_id": "zayanhugsAI/pulsenet"\n    },\n    "map_the_meal_gap": {\n        "cache_location": "/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--map_the_meal_gap/snapshots/00ec583848152c3e1fb01dd2809c1850c577881a",\n        "repo_id": "zayanhugsAI/map_the_meal_gap"\n    },\n    "social_vulnerability_index": {\n        "cache_location": "/Users/zayan/.cache/huggingface/hub/datasets--zayanhugsAI--social_vulnerability_index/snapshots/9bb6f44cb04883ba56fd228c4ca50b922d0a4e1f",\n        "repo_id": "zayanhugsAI/social_vulnerability_index"\n    }\n}'

# %%
import os

manifest_path = "/home/zayan/Documents/code/personal_repos/research_agentic_salmonella_langgraph/data_manifest.json"
if not os.path.exists(manifest_path):
    raise FileNotFoundError(f"Manifest file does not exist at {manifest_path}. Please check the path.")

manifest = load_data_manifest(manifest_path)

df_heads = get_df_heads_from_manifest(manifest)
df_heads
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 9
#       5     raise FileNotFoundError(f"Manifest file does not exist at {manifest_path}. Please check the path.")
#       7 manifest = load_data_manifest(manifest_path)
# ----> 9 df_heads = get_df_heads_from_manifest(manifest)
#      10 df_heads
#
# Cell In[8], line 54, in get_df_heads_from_manifest(manifest)
#      44 def get_df_heads_from_manifest(manifest: dict[str, dict[str, str]]) -> dict[str, str]:
#      45     """
#      46     Extracts DataFrame heads from a manifest dictionary.
#      47
#    (...)     52         dict: Dictionary with sheet names as keys and DataFrame heads in markdown format as values.
#      53     """
# ---> 54     from .tools import get_glob_files
#      55     from pathlib import Path
#      56     import pandas as pd
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# # Bedrock

# %%
from sparq.architectures.v1.settings import *
from sparq.settings import ENVSettings
from sparq.utils.get_llm import get_llm

# %%
v1_settings = V1Settings()

print("="*50)
print("Model config")
v1_settings.model_dump()
# Out:
# ==================================================
# Model config
# {'test_query': 'What are the main factors contributing to salmonella rates in Missouri in a statistical sense?',
#  'llm_config': {'router': {'provider': 'aws_bedrock',
#    'model_name': 'us.anthropic.claude-haiku-4-5-20251001-v1:0',
#    'max_tokens': None,
#    'temperature': None,
#    'top_p': None,
#    'reasoning': None,
#    'recursion_limit': 20},
#   'planner': {'provider': 'aws_bedrock',
#    'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0',
#    'max_tokens': None,
#    'temperature': None,
#    'top_p': None,
#    'reasoning': None,
#    'recursion_limit': 20},
#   'executor': {'provider': 'aws_bedrock',
#    'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0',
#    'max_tokens': None,
#    'temperature': None,
#    'top_p': None,
#    'reasoning': None,
#    'recursion_limit': 200},
#   'aggregator': {'provider': 'aws_bedrock',
#    'model_name': 'us.anthropic.claude-haiku-4-5-20251001-v1:0',
#    'max_tokens': None,
#    'temperature': None,
#    'top_p': None,
#    'reasoning': None,
#    'recursion_limit': 20}},
#  'paths': {'prompts_dir': PosixPath('/home/zayan/Documents/code/mine/SPARQ/src/sparq/architectures/v1/prompts'),
#   'output_dir': PosixPath('/home/zayan/tmp/sparq/output'),
#   'output_stem': None,
#   'run_dir': PosixPath('/home/zayan/tmp/sparq/output/09-08-2026_21-11-23')}}

# %%
# AWS profile and region
e = ENVSettings()
print(f"AWS profile: {e.aws_profile}")
print(f"AWS region: {e.aws_region}")
# Out:
# AWS profile: sensd
# AWS region: us-east-1

# %%
model = v1_settings.llm_config.router.model_name
provider = v1_settings.llm_config.router.provider

print(f"model: {model}")
print(f"provider: {provider}")
llm = get_llm(model, provider)

llm.invoke("hi")
# Out:
# model: us.anthropic.claude-haiku-4-5-20251001-v1:0
# provider: aws_bedrock
# ---------------------------------------------------------------------------
# TokenRetrievalError                       Traceback (most recent call last)
# Cell In[20], line 8
#       5 print(f"provider: {provider}")
#       6 llm = get_llm(model, provider)
# ----> 8 llm.invoke("hi")
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/langchain_aws/chat_models/bedrock_converse.py:1214, in ChatBedrockConverse._generate(self, messages, stop, run_manager, **kwargs)
#    1212 logger.info("Using Bedrock Converse API to generate response")
#    1213 try:
# -> 1214     response = self.client.converse(
#    1215         messages=bedrock_messages, system=system, **params
#    1216     )
#    1217 except ClientError as e:
#    1218     _handle_bedrock_error(e)
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/client.py:606, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     602     raise TypeError(
#     603         f"{py_operation_name}() only accepts keyword arguments."
#     604     )
#     605 # The "self" in this scope is referring to the BaseClient.
# --> 606 return self._make_api_call(operation_name, kwargs)
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/client.py:1076, in BaseClient._make_api_call(self, operation_name, api_params)
#    1072     maybe_compress_request(
#    1073         self.meta.config, request_dict, operation_model
#    1074     )
#    1075     apply_request_checksum(request_dict)
# -> 1076     http, parsed_response = self._make_request(
#    1077         operation_model, request_dict, request_context
#    1078     )
#    1080 self.meta.events.emit(
#    1081     f'after-call.{service_id}.{operation_name}',
#    1082     http_response=http,
#    (...)   1085     context=request_context,
#    1086 )
#    1088 if http.status_code >= 300:
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/client.py:1100, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1098 def _make_request(self, operation_model, request_dict, request_context):
#    1099     try:
# -> 1100         return self._endpoint.make_request(operation_model, request_dict)
#    1101     except Exception as e:
#    1102         self.meta.events.emit(
#    1103             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#    1104             exception=e,
#    1105             context=request_context,
#    1106         )
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/endpoint.py:196, in Endpoint._send_request(self, request_dict, operation_model)
#     194 context = request_dict['context']
#     195 self._update_retries_context(context, attempts)
# --> 196 request = self.create_request(request_dict, operation_model)
#     197 success_response, exception = self._get_response(
#     198     request, operation_model, context
#     199 )
#     200 while self._needs_retry(
#     201     attempts,
#     202     operation_model,
#    (...)    205     exception,
#     206 ):
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/endpoint.py:132, in Endpoint.create_request(self, params, operation_model)
#     130     service_id = operation_model.service_model.service_id.hyphenize()
#     131     event_name = f'request-created.{service_id}.{operation_model.name}'
# --> 132     self._event_emitter.emit(
#     133         event_name,
#     134         request=request,
#     135         operation_name=operation_model.name,
#     136     )
#     137 prepared_request = self.prepare_request(request)
#     138 return prepared_request
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     410 def emit(self, event_name, **kwargs):
#     411     aliased_event_name = self._alias_event_name(event_name)
# --> 412     return self._emitter.emit(aliased_event_name, **kwargs)
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     245 def emit(self, event_name, **kwargs):
#     246     """
#     247     Emit an event by name with arguments passed as keyword args.
#     248
#    (...)    254              handlers.
#     255     """
# --> 256     return self._emit(event_name, kwargs)
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     237 for handler in handlers_to_call:
#     238     logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239     response = handler(**kwargs)
#     240     responses.append((handler, response))
#     241     if stop_on_response and response is not None:
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/signers.py:108, in RequestSigner.handler(self, operation_name, request, **kwargs)
#     103 def handler(self, operation_name=None, request=None, **kwargs):
#     104     # This is typically hooked up to the "request-created" event
#     105     # from a client's event emitter.  When a new request is created
#     106     # this method is invoked to sign the request.
#     107     # Don't call this method directly.
# --> 108     return self.sign(operation_name, request)
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/signers.py:191, in RequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     185     self._resolve_identity_cache(
#     186         kwargs,
#     187         signing_context['identity_cache'],
#     188         signing_context['cache_key'],
#     189     )
#     190 try:
# --> 191     auth = self.get_auth_instance(**kwargs)
#     192 except UnknownSignatureVersionError as e:
#     193     if signing_type != 'standard':
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/signers.py:312, in RequestSigner.get_auth_instance(self, signing_name, region_name, signature_version, request_credentials, **kwargs)
#     310 frozen_credentials = None
#     311 if credentials is not None:
# --> 312     frozen_credentials = credentials.get_frozen_credentials()
#     313 kwargs['credentials'] = frozen_credentials
#     314 if cls.REQUIRES_REGION:
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/credentials.py:697, in RefreshableCredentials.get_frozen_credentials(self)
#     663 def get_frozen_credentials(self):
#     664     """Return immutable credentials.
#     665
#     666     The ``access_key``, ``secret_key``, and ``token`` properties
#    (...)    695
#     696     """
# --> 697     self._refresh()
#     698     return self._frozen_credentials
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/credentials.py:584, in RefreshableCredentials._refresh(self)
#     580         return
#     581     is_mandatory_refresh = self.refresh_needed(
#     582         self._mandatory_refresh_timeout
#     583     )
# --> 584     self._protected_refresh(is_mandatory=is_mandatory_refresh)
#     585     return
#     586 finally:
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/credentials.py:600, in RefreshableCredentials._protected_refresh(self, is_mandatory)
#     596 def _protected_refresh(self, is_mandatory):
#     597     # precondition: this method should only be called if you've acquired
#     598     # the self._refresh_lock.
#     599     try:
# --> 600         metadata = self._refresh_using()
#     601     except Exception:
#     602         period_name = 'mandatory' if is_mandatory else 'advisory'
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/credentials.py:750, in CachedCredentialFetcher.fetch_credentials(self)
#     749 def fetch_credentials(self):
# --> 750     return self._get_cached_credentials()
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/credentials.py:760, in CachedCredentialFetcher._get_cached_credentials(self)
#     758 response = self._load_from_cache()
#     759 if response is None:
# --> 760     response = self._get_credentials()
#     761     self._write_to_cache(response)
#     762 else:
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/credentials.py:2317, in SSOCredentialFetcher._get_credentials(self)
#    2315 if self._token_provider:
#    2316     initial_token_data = self._token_provider.load_token()
# -> 2317     token = initial_token_data.get_frozen_token().token
#    2318 else:
#    2319     token_dict = self._token_loader(self._start_url)
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/tokens.py:89, in DeferredRefreshableToken.get_frozen_token(self)
#      88 def get_frozen_token(self):
# ---> 89     self._refresh()
#      90     return self._frozen_token
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/tokens.py:102, in DeferredRefreshableToken._refresh(self)
#     100 if self._refresh_lock.acquire(block_for_refresh):
#     101     try:
# --> 102         self._protected_refresh()
#     103     finally:
#     104         self._refresh_lock.release()
#
# File ~/Documents/code/mine/SPARQ/.venv/lib/python3.13/site-packages/botocore/tokens.py:129, in DeferredRefreshableToken._protected_refresh(self)
#     125         raise
#     127 if self._is_expired():
#     128     # Fresh credentials should never be expired
# --> 129     raise TokenRetrievalError(
#     130         provider=self.method,
#     131         error_msg="Token has expired and refresh failed",
#     132     )
#
# TokenRetrievalError: Error when retrieving token from sso: Token has expired and refresh failed
